# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime
import requests
from bs4 import BeautifulSoup
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
cid = 'e84cff85bea3495e8990433906f44b8b'
secret = '03905a2c5ef744bf908ece068c9037b2'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager
=
client_credentials_manager)

data = pd.read_csv('~/Downloads/418FinalProject-main/data.csv')

data
# Out:
#        Unnamed: 0    WeekID  Week Position  \
# 0              23   7/30/66           12.0
# 1              24   4/15/67           12.0
# 2             821    8/2/58            1.0
# 3             822   12/2/95            1.0
# 4             823  10/11/97            1.0
# ...           ...       ...            ...
# 15919          13    4/3/21            NaN
# 15920          14   4/10/21            NaN
# 15921          15   4/17/21            NaN
# 15922          16   4/24/21            NaN
# 15923          17    5/1/21            NaN
#
#                                                     Song  \
# 0                                       Paperback Writer
# 1                                             Penny Lane
# 2                                       Poor Little Fool
# 3                                          One Sweet Day
# 4      Candle In The Wind 1997/Something About The Wa...
# ...                                                  ...
# ...

# %%
#del data['Unnamed: 0']
#del data['Date']

# %%
data
# Out:
#          WeekID  Week Position  \
# 0       7/30/66           12.0
# 1       4/15/67           12.0
# 2        8/2/58            1.0
# 3       12/2/95            1.0
# 4      10/11/97            1.0
# ...         ...            ...
# 15919    4/3/21            NaN
# 15920   4/10/21            NaN
# 15921   4/17/21            NaN
# 15922   4/24/21            NaN
# 15923    5/1/21            NaN
#
#                                                     Song  \
# 0                                       Paperback Writer
# 1                                             Penny Lane
# 2                                       Poor Little Fool
# 3                                          One Sweet Day
# 4      Candle In The Wind 1997/Something About The Wa...
# ...                                                  ...
# 15919                                            Peaches
# 15920                     Montero (Call Me by Your Name)
# 15921                                Leave the Door Open
# ...

# %%
data = data[data['Link'].notna()]

# %%
data
# Out:
#          WeekID  Week Position  \
# 0       7/30/66           12.0
# 1       4/15/67           12.0
# 2        8/2/58            1.0
# 3       12/2/95            1.0
# 4      10/11/97            1.0
# ...         ...            ...
# 15918   3/27/21            NaN
# 15920   4/10/21            NaN
# 15921   4/17/21            NaN
# 15922   4/24/21            NaN
# 15923    5/1/21            NaN
#
#                                                     Song  \
# 0                                       Paperback Writer
# 1                                             Penny Lane
# 2                                       Poor Little Fool
# 3                                          One Sweet Day
# 4      Candle In The Wind 1997/Something About The Wa...
# ...                                                  ...
# 15918                                                 Up
# 15920                     Montero (Call Me by Your Name)
# 15921                                Leave the Door Open
# ...

# %%
songdata = []
for i in data['Link'].values:
    songdata.append(sp.audio_features(i)[0])
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# ...

# %%
songdata = pd.DataFrame(songdata)[['danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']]
songdata
# Out:
#       danceability  energy  key  loudness  speechiness  acousticness  \
# 0            0.472   0.856    7    -6.030       0.0562       0.14700
# 1            0.651   0.488    9    -8.220       0.0316       0.21200
# 2            0.474   0.338    0   -11.528       0.0299       0.64800
# 3            0.666   0.297    1   -15.936       0.0360       0.80700
# 4            0.480   0.628    6    -7.643       0.0262       0.17400
# ...            ...     ...  ...       ...          ...           ...
# 1525         0.720   0.672    7    -6.852       0.0551       0.00900
# 1526         0.697   0.498    9    -9.147       0.0419       0.10100
# 1527         0.724   0.704   11    -8.258       0.0511       0.11300
# 1528         0.617   0.717   10    -7.858       0.1530       0.00564
# 1529         0.789   0.706   11    -4.233       0.0429       0.11200
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000003    0.5950    0.841   78.696       138200
# ...

# %%
data['WeekID'] = pd.to_datetime(data['WeekID'])
# Out:
# <ipython-input-8-9add8cab9176>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['WeekID'] = pd.to_datetime(data['WeekID'])

# %%
data['Year'] = data['WeekID'].dt.year
data['Month'] = data['WeekID'].dt.month
# Out:
# <ipython-input-9-b30a92ce969f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Year'] = data['WeekID'].dt.year
# <ipython-input-9-b30a92ce969f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Month'] = data['WeekID'].dt.month

# %%
df = pd.concat([data, songdata], axis = 1)[['Song', 'Performer', 'Peak Position', 'Weeks on Chart', 'Song ID', 'Year', 'Month', 'danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature', 'Link']]

# %%
df2 = df.drop_duplicates(subset = ['Song'])

# %%
years = df2.loc[(df2['Year'] >= 2058) & (df2['Year'] <= 2070)]
years['Year'] = years['Year'] - 100
years2 = years.groupby('Year')['Peak Position'].count()
# Out:
# <ipython-input-12-aa0a9673859c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   years['Year'] = years['Year'] - 100

# %%
from matplotlib.pyplot import figure
figure(figsize=(10, 6))
years2.plot(xlabel = 'Years', ylabel = '# of Number Ones', title = '# of Number One Singles in the 50s and 60s', kind = 'bar')
# Out:
# <AxesSubplot:title={'center':'# of Number One Singles in the 50s and 60s'}, xlabel='Years', ylabel='# of Number Ones'>

# %%
years = df2.loc[(df2['Year'] >= 1970) & (df2['Year'] <= 1979)]
years2 = years.groupby('Year')['Peak Position'].count()

# %%
figure(figsize=(10, 6))
years2.plot(xlabel = 'Years', ylabel = '# of Number Ones', title = '# of Number One Singles in the 70s', kind = 'bar', color = 'red')
# Out:
# <AxesSubplot:title={'center':'# of Number One Singles in the 70s'}, xlabel='Years', ylabel='# of Number Ones'>

# %%
years = df2.loc[(df2['Year'] >= 1980) & (df2['Year'] <= 1989)]
years2 = years.groupby('Year')['Peak Position'].count()
figure(figsize=(10, 6))
years2.plot(xlabel = 'Years', ylabel = '# of Number Ones', title = '# of Number One Singles in the 80s', kind = 'bar', color = 'orange')
# Out:
# <AxesSubplot:title={'center':'# of Number One Singles in the 80s'}, xlabel='Years', ylabel='# of Number Ones'>

# %%
years = df2.loc[(df2['Year'] >= 1990) & (df2['Year'] <= 1999)]
years2 = years.groupby('Year')['Peak Position'].count()
figure(figsize=(10, 6))
years2.plot(xlabel = 'Years', ylabel = '# of Number Ones', title = '# of Number One Singles in the 90s', kind = 'bar', color = 'green')
# Out:
# <AxesSubplot:title={'center':'# of Number One Singles in the 90s'}, xlabel='Years', ylabel='# of Number Ones'>

# %%
years = df2.loc[(df2['Year'] >= 2000) & (df2['Year'] <= 2009)]
years2 = years.groupby('Year')['Peak Position'].count()
figure(figsize=(10, 6))
years2.plot(xlabel = 'Years', ylabel = '# of Number Ones', title = '# of Number One Singles in the 00s', kind = 'bar', color = 'purple')
# Out:
# <AxesSubplot:title={'center':'# of Number One Singles in the 00s'}, xlabel='Years', ylabel='# of Number Ones'>

# %%
years = df2.loc[(df2['Year'] >= 2010) & (df2['Year'] <= 2021)]
years2 = years.groupby('Year')['Peak Position'].count()
figure(figsize=(10, 6))
years2.plot(xlabel = 'Years', ylabel = '# of Number Ones', title = '# of Number One Singles in the 2010s and 2020s', kind = 'bar', color = 'pink')
# Out:
# <AxesSubplot:title={'center':'# of Number One Singles in the 2010s and 2020s'}, xlabel='Years', ylabel='# of Number Ones'>

# %%
artists = df2.groupby('Performer')['Peak Position'].count().sort_values(ascending=False)[:10]
artists
figure(figsize=(10, 6))
artists.plot(xlabel = 'Artists', ylabel = '# of Number Ones', title = 'Top 10 Artists with the Most Number One Singles of All Time ', kind = 'barh')
# Out:
# <AxesSubplot:title={'center':'Top 10 Artists with the Most Number One Singles of All Time '}, ylabel='Artists'>

# %%
years = df2.loc[(df2['Year'] >= 2058) & (df2['Year'] <= 2070)]
years['Year'] = years['Year'] - 100
artists = years.groupby('Performer')['Peak Position'].count().sort_values(ascending=False)[:10]
artists
figure(figsize=(10, 6))
artists.plot(xlabel = 'Artists', ylabel = '# of Number Ones', title = 'Top 10 Artists with the Most Number One Singles in the 50s and 60s ', kind = 'barh')
# Out:
# <ipython-input-21-2a812ecf0666>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   years['Year'] = years['Year'] - 100
# <AxesSubplot:title={'center':'Top 10 Artists with the Most Number One Singles in the 50s and 60s '}, ylabel='Artists'>

# %%
years = df2.loc[(df2['Year'] >= 1971) & (df2['Year'] <= 1979)]
artists = years.groupby('Performer')['Peak Position'].count().sort_values(ascending=False)[:10]
artists
figure(figsize=(10, 6))
artists.plot(xlabel = 'Artists', ylabel = '# of Number Ones', title = 'Top 10 Artists with the Most Number One Singles in the 70s ', kind = 'barh', color = 'magenta')
# Out:
# <AxesSubplot:title={'center':'Top 10 Artists with the Most Number One Singles in the 70s '}, ylabel='Artists'>

# %%
years = df2.loc[(df2['Year'] >= 1980) & (df2['Year'] <= 1989)]
artists = years.groupby('Performer')['Peak Position'].count().sort_values(ascending=False)[:10]
artists
figure(figsize=(10, 6))
artists.plot(xlabel = 'Artists', ylabel = '# of Number Ones', title = 'Top 10 Artists with the Most Number One Singles in the 80s ', kind = 'barh', color = 'lightcoral')
# Out:
# <AxesSubplot:title={'center':'Top 10 Artists with the Most Number One Singles in the 80s '}, ylabel='Artists'>

# %%
years = df2.loc[(df2['Year'] >= 1990) & (df2['Year'] <= 1999)]
artists = years.groupby('Performer')['Peak Position'].count().sort_values(ascending=False)[:10]
artists
figure(figsize=(10, 6))
artists.plot(xlabel = 'Artists', ylabel = '# of Number Ones', title = 'Top 10 Artists with the Most Number One Singles in the 90s ', kind = 'barh', color = 'darkolivegreen')
# Out:
# <AxesSubplot:title={'center':'Top 10 Artists with the Most Number One Singles in the 90s '}, ylabel='Artists'>

# %%
years = df2.loc[(df2['Year'] >= 2000) & (df2['Year'] <= 2009)]
artists = years.groupby('Performer')['Peak Position'].count().sort_values(ascending=False)[:10]
artists
figure(figsize=(10, 6))
artists.plot(xlabel = 'Artists', ylabel = '# of Number Ones', title = 'Top 10 Artists with the Most Number One Singles in the 00s ', kind = 'barh', color = 'goldenrod')
# Out:
# <AxesSubplot:title={'center':'Top 10 Artists with the Most Number One Singles in the 00s '}, ylabel='Artists'>

# %%
years = df2.loc[(df2['Year'] >= 2010) & (df2['Year'] <= 2021)]
artists = years.groupby('Performer')['Peak Position'].count().sort_values(ascending=False)[:10]
artists
figure(figsize=(10, 6))
artists.plot(xlabel = 'Artists', ylabel = '# of Number Ones', title = 'Top 10 Artists with the Most Number One Singles in the 2010s and 2020s', kind = 'barh', color = 'mediumslateblue')
# Out:
# <AxesSubplot:title={'center':'Top 10 Artists with the Most Number One Singles in the 2010s and 2020s'}, ylabel='Artists'>

# %%
years = df2.loc[(df2['Performer'] == 'Mariah Carey')]
artists = years.groupby('Year')['Peak Position'].count()
labels = '1990', '1991', '1992', '1993', '1995', '1996', '1997', '1998', '2005', '2006', '2008', '2019', '2020'
figure(figsize=(10, 10))
artists.plot(title = 'Number 1 Singles for Mariah Carey', kind = 'pie', autopct='%1.1f%%')
plt.legend(artists, loc = 'center')

# %%
years = df2.loc[(df2['Year'] >= 2010) & (df2['Year'] <= 2021)]
valence = years.groupby('Year')['valence'].mean()
valence
# Out:
# Year
# 2010.0    0.520571
# 2011.0    0.422000
# 2012.0    0.604000
# 2013.0    0.276400
# 2014.0    0.648000
# 2015.0    0.540600
# 2016.0    0.645000
# 2017.0    0.656750
# 2018.0    0.607000
# 2019.0    0.625625
# 2020.0         NaN
# 2021.0         NaN
# Name: valence, dtype: float64

# %%
figure(figsize=(10, 6))
valence.plot(xlabel = 'Year', ylabel = 'Valence', title = 'Average Valences from the Past Several Years', kind = 'box')
# Out:
# <AxesSubplot:title={'center':'Average Valences from the Past Several Years'}, ylabel='Valence'>

# %%
years = df2.loc[(df2['Year'] >= 1971) & (df2['Year'] <= 1979)]
valence = years.groupby('Year')['valence'].mean()
figure(figsize=(10, 6))
valence.plot(xlabel = 'Year', ylabel = 'Valence', title = 'Average Valences from the 70s', kind = 'box')
# Out:
# <AxesSubplot:title={'center':'Average Valences from the 70s'}, ylabel='Valence'>

# %%
years = df2.loc[(df2['Year'] >= 2010) & (df2['Year'] <= 2021)]
dance = years.groupby('Year')['danceability'].mean()
dance
# Out:
# Year
# 2010.0    0.578143
# 2011.0    0.711000
# 2012.0    0.602500
# 2013.0    0.502000
# 2014.0    0.612000
# 2015.0    0.539400
# 2016.0    0.622750
# 2017.0    0.617500
# 2018.0    0.608750
# 2019.0    0.673625
# 2020.0         NaN
# 2021.0         NaN
# Name: danceability, dtype: float64

# %%
figure(figsize=(10, 6))
dance.plot(xlabel = 'Year', ylabel = 'Danceability', title = 'Average Danceability from 2010-2019', kind = 'area')
# Out:
# <AxesSubplot:title={'center':'Average Danceability from 2010-2019'}, xlabel='Year', ylabel='Danceability'>

# %%
years = df2.loc[(df2['Year'] >= 1990) & (df2['Year'] <= 1999)]
dance = years.groupby('Year')['danceability'].mean()
dance
figure(figsize=(10, 6))
dance.plot(xlabel = 'Year', ylabel = 'Danceability', title = 'Average Danceability from 1990-1999', kind = 'area')
# Out:
# <AxesSubplot:title={'center':'Average Danceability from 1990-1999'}, xlabel='Year', ylabel='Danceability'>

# %%
years = df2.loc[(df2['Year'] >= 2058) & (df2['Year'] <= 2070)]
years['Year'] = years['Year'] - 100
loud = years.groupby('Year')['loudness'].mean()
figure(figsize=(10, 6))
loud.plot(xlabel = 'Year', ylabel = 'Loudness', title = 'Music Loudness from the 50s and 60s', kind = 'line', color = 'navy')
# Out:
# <ipython-input-34-72264950ec02>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   years['Year'] = years['Year'] - 100
# <AxesSubplot:title={'center':'Music Loudness from the 50s and 60s'}, xlabel='Year', ylabel='Loudness'>

# %%
years = df2.loc[(df2['Year'] >= 2000) & (df2['Year'] <= 2009)]
loud = years.groupby('Year')['loudness'].mean()
figure(figsize=(10, 6))
loud.plot(xlabel = 'Year', ylabel = 'Loudness', title = 'Music Loudness from the 2000s', kind = 'line', color = 'hotpink')
# Out:
# <AxesSubplot:title={'center':'Music Loudness from the 2000s'}, xlabel='Year', ylabel='Loudness'>

# %%
years = df2.loc[(df2['Year'] >= 2010) & (df2['Year'] <= 2021)]
loud = years.groupby('Year')['loudness'].mean()
figure(figsize=(10, 6))
loud.plot(xlabel = 'Year', ylabel = 'Loudness', title = 'Music Loudness from 2010 - 2019', kind = 'line', color = 'firebrick')
# Out:
# <AxesSubplot:title={'center':'Music Loudness from 2010 - 2019'}, xlabel='Year', ylabel='Loudness'>

# %%
years = df2.loc[(df2['Year'] >= 2010) & (df2['Year'] <= 2021)]
loud = years.groupby('Year')['energy'].mean()
soft = years.groupby('Year')['acousticness'].mean()
figure(figsize=(10, 6))
loud.plot(kind = 'line', color = 'red')
soft.plot(kind = 'line', color = 'blue')
plt.title('Energy vs Acousticness')
plt.legend()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df3 = df2.dropna()

# %%
def val (valence):
    if ((valence >= 0.000) & (valence <= 0.500)):
        return 'Low'
    else:
        return 'High'
    
df3['val2'] = df3['valence'].apply(val)
# Out:
# <ipython-input-40-5ea071d107e6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['val2'] = df3['valence'].apply(val)

# %%
df3
# Out:
#                                                    Song  \
# 0                                      Paperback Writer
# 1                                            Penny Lane
# 2                                      Poor Little Fool
# 3                                         One Sweet Day
# 4     Candle In The Wind 1997/Something About The Wa...
# ...                                                 ...
# 1517          Caribbean Queen (No More Love On The Run)
# 1519                                      Baby Got Back
# 1527                                            Believe
# 1528                                             Smooth
# 1529                                        Say My Name
#
#                          Performer  Peak Position  Weeks on Chart  \
# 0                      The Beatles            1.0             8.0
# 1                      The Beatles            1.0             8.0
# 2                     Ricky Nelson            1.0             1.0
# ...

# %%
X = df3[['Year', 'energy', 'tempo','danceability']]
y = df3['val2']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 6)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
predict = classifier.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, predict))
print(classification_report(y_test, predict))
cm = confusion_matrix(y_test, predict)
# Out:
# [[44 14]
#  [17 11]]
#               precision    recall  f1-score   support
#
#         High       0.72      0.76      0.74        58
#          Low       0.44      0.39      0.42        28
#
#     accuracy                           0.64        86
#    macro avg       0.58      0.58      0.58        86
# weighted avg       0.63      0.64      0.63        86

# %%
plt.figure(figsize = (10, 6))
sns.heatmap(cm, annot = True)
plt.xlabel('Predictions')
plt.ylabel('Actual values')
plt.title('Confusion Matrix for the Valence')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for the Valence')

# %%
def temp (tempo):
    if ((tempo >= 0.0) & (tempo <= 80.0)):
        return 'Slow'
    elif ((tempo > 80.0) & (tempo <= 110.0)):
        return 'Moderate'
    else:
        return 'Fast'
    
df3['tempi'] = df3['tempo'].apply(temp)
# Out:
# <ipython-input-48-4b4d6888193a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['tempi'] = df3['tempo'].apply(temp)

# %%
X = df3[['Year', 'energy', 'liveness', 'speechiness']]
y = df3['tempi']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
classifier = KNeighborsClassifier(n_neighbors = 5)
classifier.fit(X_train, y_train)
predict = classifier.predict(X_test)
print(confusion_matrix(y_test, predict))
print(classification_report(y_test, predict))
cm2 = confusion_matrix(y_test, predict)
# Out:
# [[35  8  4]
#  [19 12  1]
#  [ 3  1  3]]
#               precision    recall  f1-score   support
#
#         Fast       0.61      0.74      0.67        47
#     Moderate       0.57      0.38      0.45        32
#         Slow       0.38      0.43      0.40         7
#
#     accuracy                           0.58        86
#    macro avg       0.52      0.52      0.51        86
# weighted avg       0.58      0.58      0.57        86

# %%
plt.figure(figsize = (10, 6))
sns.heatmap(cm2, annot = True)
plt.xlabel('Predictions')
plt.ylabel('Actual values')
plt.title('Confusion Matrix for the Tempo')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for the Tempo')

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(n_estimators = 20, random_state = 0)

# %%
from sklearn.metrics import accuracy_score
model2.fit(X_train, y_train)
predict = model2.predict(X_test)
print(confusion_matrix(y_test, predict))
print(classification_report(y_test, predict))
print('Accuracy score:', accuracy_score(y_test, predict))
# Out:
# [[39  7  1]
#  [13 19  0]
#  [ 3  0  4]]
#               precision    recall  f1-score   support
#
#         Fast       0.71      0.83      0.76        47
#     Moderate       0.73      0.59      0.66        32
#         Slow       0.80      0.57      0.67         7
#
#     accuracy                           0.72        86
#    macro avg       0.75      0.66      0.70        86
# weighted avg       0.72      0.72      0.72        86
#
# Accuracy score: 0.7209302325581395

# %%
names = ['Year', 'energy', 'liveness', 'speechiness']
features = pd.Series(model2.feature_importances_, index = names).sort_values(ascending = False)
features
# Out:
# energy         0.299243
# speechiness    0.270221
# liveness       0.265617
# Year           0.164920
# dtype: float64

# %%
figure(figsize = (10, 6))
sns.barplot(features, features.index)
plt.title('Feature Importance for Tempo')
plt.xlabel('Importance')
plt.ylabel('Features')
# Out:
# /Users/matthewghuneim/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Features')

# %%
def acou (acc):
    if ((acc >= 0.000) & (acc <= 0.300)):
        return 0
    elif ((acc > 0.300) & (acc <= 0.700)):
        return 1
    else:
        return 2
    
df3['acc2'] = df3['acousticness'].apply(acou)
# Out:
# <ipython-input-56-8c352ed09917>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['acc2'] = df3['acousticness'].apply(acou)

# %%
df3
# Out:
#                                                    Song  \
# 0                                      Paperback Writer
# 1                                            Penny Lane
# 2                                      Poor Little Fool
# 3                                         One Sweet Day
# 4     Candle In The Wind 1997/Something About The Wa...
# ...                                                 ...
# 1517          Caribbean Queen (No More Love On The Run)
# 1519                                      Baby Got Back
# 1527                                            Believe
# 1528                                             Smooth
# 1529                                        Say My Name
#
#                          Performer  Peak Position  Weeks on Chart  \
# 0                      The Beatles            1.0             8.0
# 1                      The Beatles            1.0             8.0
# 2                     Ricky Nelson            1.0             1.0
# ...

# %%
X = df3[['Year', 'liveness', 'instrumentalness', 'valence']]
y = df3['acc2']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
model2 = RandomForestClassifier(n_estimators = 20, random_state = 0)
model2.fit(X_train, y_train)
predict = model2.predict(X_test)
print(confusion_matrix(y_test, predict))
print(classification_report(y_test, predict))
print('Accuracy score:', accuracy_score(y_test, predict))
# Out:
# [[49  1  0]
#  [11 10  3]
#  [ 8  1  3]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.98      0.83        50
#            1       0.83      0.42      0.56        24
#            2       0.50      0.25      0.33        12
#
#     accuracy                           0.72        86
#    macro avg       0.68      0.55      0.57        86
# weighted avg       0.72      0.72      0.68        86
#
# Accuracy score: 0.7209302325581395

# %%
names = ['Year', 'liveness', 'instrumentalness', 'valence']
features = pd.Series(model2.feature_importances_, index = names).sort_values(ascending = False)
features
# Out:
# valence             0.315308
# liveness            0.290195
# Year                0.223966
# instrumentalness    0.170531
# dtype: float64

# %%
figure(figsize = (10, 6))
sns.barplot(features, features.index)
plt.title('Feature Importance for Acousticness')
plt.xlabel('Importance')
plt.ylabel('Features')
# Out:
# /Users/matthewghuneim/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Features')

# %%
def dancey (dance):
    if ((dance >= 0.000) & (dance <= 0.300)):
        return 0
    elif ((dance > 0.300) & (dance <= 0.700)):
        return 1
    else:
        return 2
    
df3['dance2'] = df3['danceability'].apply(dancey)
# Out:
# <ipython-input-62-cdf76d30ffec>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['dance2'] = df3['danceability'].apply(dancey)

# %%
X = df3[['Year', 'liveness', 'energy', 'valence', 'duration_ms']]
y = df3['dance2']

# %%
from sklearn.tree import DecisionTreeClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
model3 = DecisionTreeClassifier(criterion = 'entropy')
model3.fit(X_train, y_train)
predict = model3.predict(X_test)
print(confusion_matrix(y_test, predict))
print(classification_report(y_test, predict))
print('Accuracy score:', accuracy_score(y_test, predict))
# Out:
# [[ 0  2  0]
#  [ 0 42 10]
#  [ 0 10 22]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.78      0.81      0.79        52
#            2       0.69      0.69      0.69        32
#
#     accuracy                           0.74        86
#    macro avg       0.49      0.50      0.49        86
# weighted avg       0.73      0.74      0.73        86
#
# Accuracy score: 0.7441860465116279
# /Users/matthewghuneim/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
